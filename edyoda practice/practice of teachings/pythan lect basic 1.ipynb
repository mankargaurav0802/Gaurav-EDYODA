# %%
for i in range (1,35):
    dib = 7
    print("{} is divisable by 7 ".format(i%dib==0))
# Out:
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# True is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# True is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# True is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# True is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7
# False is divisable by 7

# %%
#Gaurav
for i in range(1,11):
   print("{}*{}={}".format(i,i,i*i))
# Out:
# 1*1=1
# 2*2=4
# 3*3=9
# 4*4=16
# 5*5=25
# 6*6=36
# 7*7=49
# 8*8=64
# 9*9=81
# 10*10=100

# %%
#Gaurav
for i in range(1,21):
   print("{}^{}={}".format(i,i,i*i))
# Out:
# 1^1=1
# 2^2=4
# 3^3=9
# 4^4=16
# 5^5=25
# 6^6=36
# 7^7=49
# 8^8=64
# 9^9=81
# 10^10=100
# 11^11=121
# 12^12=144
# 13^13=169
# 14^14=196
# 15^15=225
# 16^16=256
# 17^17=289
# 18^18=324
# 19^19=361
# 20^20=400

# %%
for i in range(1,10):
    print("{}/2={}".format(i,i/2))
# Out:
# 1/2=0.5
# 2/2=1.0
# 3/2=1.5
# 4/2=2.0
# 5/2=2.5
# 6/2=3.0
# 7/2=3.5
# 8/2=4.0
# 9/2=4.5

# %%
for i in range(10,20):
        print("{}-4={}".format(i,i-4))
# Out:
# 10-4=6
# 11-4=7
# 12-4=8
# 13-4=9
# 14-4=10
# 15-4=11
# 16-4=12
# 17-4=13
# 18-4=14
# 19-4=15

# %%
#for average of 5 num
a=10
b=20
c=30
d=40
e=50
#print((a+b+c+d+e)/5)
print("avg is {}".format(a+b+c+d+e/5))
# Out:
# avg is 110.0

# %%
# for no diceded

list_q=[10,20,30,40,50]
sum(list_q)
# Out:
# 150

# %%
#cubes from 1 to 20
for i in range(1,21):
        print("{}={}*{}*{}={}".format(i,i,i,i,i*i*i))
# Out:
# 1=1*1*1=1
# 2=2*2*2=8
# 3=3*3*3=27
# 4=4*4*4=64
# 5=5*5*5=125
# 6=6*6*6=216
# 7=7*7*7=343
# 8=8*8*8=512
# 9=9*9*9=729
# 10=10*10*10=1000
# 11=11*11*11=1331
# 12=12*12*12=1728
# 13=13*13*13=2197
# 14=14*14*14=2744
# 15=15*15*15=3375
# 16=16*16*16=4096
# 17=17*17*17=4913
# 18=18*18*18=5832
# 19=19*19*19=6859
# 20=20*20*20=8000

# %%
#cubes from 1 to 20
for i in range(1,21):
        print("{}*{}*{}={}".format(i,i,i,i*i*i))
# Out:
# 1*1*1=1
# 2*2*2=8
# 3*3*3=27
# 4*4*4=64
# 5*5*5=125
# 6*6*6=216
# 7*7*7=343
# 8*8*8=512
# 9*9*9=729
# 10*10*10=1000
# 11*11*11=1331
# 12*12*12=1728
# 13*13*13=2197
# 14*14*14=2744
# 15*15*15=3375
# 16*16*16=4096
# 17*17*17=4913
# 18*18*18=5832
# 19*19*19=6859
# 20*20*20=8000

# %%
animals=(1,2,3,4)
print(type(animals))
# Out:
# <class 'tuple'>

# %%
for num in range (250,2026):
    if num%4==0 and num%100!=0:
     print("{0} is leap year".format(num))
# Out:
# 252 is leap year
# 256 is leap year
# 260 is leap year
# 264 is leap year
# 268 is leap year
# 272 is leap year
# 276 is leap year
# 280 is leap year
# 284 is leap year
# 288 is leap year
# 292 is leap year
# 296 is leap year
# 304 is leap year
# 308 is leap year
# 312 is leap year
# 316 is leap year
# 320 is leap year
# 324 is leap year
# 328 is leap year
# 332 is leap year
# 336 is leap year
# 340 is leap year
# 344 is leap year
# 348 is leap year
# 352 is leap year
# 356 is leap year
# 360 is leap year
# 364 is leap year
# 368 is leap year
# 372 is leap year
# 376 is leap year
# 380 is leap year
# 384 is leap year
# 388 is leap year
# 392 is leap year
# 396 is leap year
# 404 is leap year
# 408 is leap year
# 412 is leap year
# 416 is leap year
# 420 is leap year
# 424 is leap year
# 428 is leap year
# 432 is leap year
# 436 is leap year
# 440 is leap year
# 444 is leap year
# 448 is leap year
# 452 is leap year
# 456 is leap year
# 460 is leap year
# 464 is leap year
# ...

# %%
##get the sum of all the even numbers from 1 to 100
addition = 0
for num in range(1,9):
    if num%2==0:
        addition=num+addition

# %%
addition
# Out:
# 20

# %%
sul=0
for num in range (250,2026):
    if num%4==0 and num%100!=0:
        sul=sul+num

# %%
sul
# Out:
# 484572

# %%
#cubes from 1 to 20
i=1
while i <20:
    print("{}={}*{}*{}={}".format(i,i,i,i,i*i*i))
    i=i+1
# Out:
# 1=1*1*1=1
# 2=2*2*2=8
# 3=3*3*3=27
# 4=4*4*4=64
# 5=5*5*5=125
# 6=6*6*6=216
# 7=7*7*7=343
# 8=8*8*8=512
# 9=9*9*9=729
# 10=10*10*10=1000
# 11=11*11*11=1331
# 12=12*12*12=1728
# 13=13*13*13=2197
# 14=14*14*14=2744
# 15=15*15*15=3375
# 16=16*16*16=4096
# 17=17*17*17=4913
# 18=18*18*18=5832
# 19=19*19*19=6859

# %%
#Write a program to print cube of numbers from 1 till 20 in the following format:
#1^3 = 1
#2^3 = 8
#3^3 = 27
#using while loop
#cubes from 1 to 20
i=1
while i <21:
    print("{}^{}={}".format(i,i,i*i*i))
    i=i+1
# Out:
# 1^1=1
# 2^2=8
# 3^3=27
# 4^4=64
# 5^5=125
# 6^6=216
# 7^7=343
# 8^8=512
# 9^9=729
# 10^10=1000
# 11^11=1331
# 12^12=1728
# 13^13=2197
# 14^14=2744
# 15^15=3375
# 16^16=4096
# 17^17=4913
# 18^18=5832
# 19^19=6859
# 20^20=8000

# %%
i=1
while i <21:
    print("{}^{}={}".format(i,i,i*i*i))
    i=i+1
# Out:
# 1^1=1
# 2^2=8
# 3^3=27
# 4^4=64
# 5^5=125
# 6^6=216
# 7^7=343
# 8^8=512
# 9^9=729
# 10^10=1000
# 11^11=1331
# 12^12=1728
# 13^13=2197
# 14^14=2744
# 15^15=3375
# 16^16=4096
# 17^17=4913
# 18^18=5832
# 19^19=6859
# 20^20=8000

# %%
#cubes from 1 to 20
i=1
while i <21:
    print("{}^{}={}".format(i,3,i*i*i))
    i=i+1
# Out:
# 1^3=1
# 2^3=8
# 3^3=27
# 4^3=64
# 5^3=125
# 6^3=216
# 7^3=343
# 8^3=512
# 9^3=729
# 10^3=1000
# 11^3=1331
# 12^3=1728
# 13^3=2197
# 14^3=2744
# 15^3=3375
# 16^3=4096
# 17^3=4913
# 18^3=5832
# 19^3=6859
# 20^3=8000
